# %% [markdown]
# # Dummy data for testing and building gesture classifiers

# %%
import random
import pandas as pd
import json

# %%
# Generate dummy data
data = []
for var2 in range(0, 5):
    for var1 in range(1, 101):
        for _ in range(30):
            first_value = var1
            second_value = var2
            float_values = [random.uniform(-1, 1) for _ in range(18)]
            row = [str(first_value), str(second_value)] + [str(value) for value in float_values]
            data.append('\t'.join(row))

# Write data to a text file
file_path = 'dummy_data.txt'
column_labels = 'iteration\tgesture_code\tsensor_1_ax\tsensor_1_ay\tsensor_1_az\tsensor_1_gx\tsensor_1_gy\tsensor_1_gz\tsensor_2_ax\tsensor_2_ay\tsensor_2_az\tsensor_2_gx\tsensor_2_gy\tsensor_2_gz\tonboard_ax\tonboard_ay\tonboard_az\tonboard_gx\tonboard_gy\tonboard_gz\n'

with open(file_path, 'w') as file:
    file.write(column_labels)
    file.write('\n'.join(data))

df_1 = pd.read_csv('dummy_data.txt',delimiter='\t')
df_1
# Out:
#        iteration  gesture_code  sensor_1_ax  sensor_1_ay  sensor_1_az  \
# 0              1             0    -0.568682     0.601786    -0.989990
# 1              1             0    -0.391427     0.330051    -0.620048
# 2              1             0    -0.740103     0.211198    -0.386086
# 3              1             0    -0.999427    -0.852134    -0.657411
# 4              1             0     0.081985     0.687038     0.787623
# ...          ...           ...          ...          ...          ...
# 14995        100             4    -0.634686    -0.499844    -0.661575
# 14996        100             4    -0.458386     0.969111     0.246843
# 14997        100             4    -0.029332     0.838320     0.031818
# 14998        100             4     0.320282    -0.653941    -0.143677
# 14999        100             4     0.035496    -0.112465     0.196240
#
#        sensor_1_gx  sensor_1_gy  sensor_1_gz  sensor_2_ax  sensor_2_ay  \
# 0         0.197055    -0.552065    -0.506900     0.517654     0.216304
# 1        -0.552683     0.307741    -0.016497    -0.366967    -0.279585
# 2        -0.244025     0.508226    -0.406110     0.347150    -0.828099
# 3        -0.303113    -0.039585    -0.869214     0.633957    -0.078813
# 4         0.529409     0.121664     0.578797    -0.321687    -0.555872
# ...            ...          ...          ...          ...          ...
# 14995    -0.534876    -0.376662     0.812224    -0.676658    -0.144459
# 14996     0.806142     0.278672     0.392789    -0.038706     0.210455
# 14997    -0.848899    -0.409863    -0.732495     0.360764     0.691196
# 14998     0.687198    -0.036014    -0.192610    -0.313601    -0.715854
# 14999    -0.867340    -0.481291     0.341578     0.212613     0.331153
#
#        sensor_2_az  sensor_2_gx  sensor_2_gy  sensor_2_gz  onboard_ax  \
# 0         0.587042    -0.507669    -0.000800    -0.071559   -0.960108
# 1         0.647960     0.538679    -0.312164    -0.580059    0.994803
# 2         0.023110     0.296853    -0.658154     0.067692   -0.097333
# 3        -0.263636     0.653180    -0.535132     0.970812   -0.499927
# 4         0.265379     0.653142    -0.813891     0.057882    0.080889
# ...            ...          ...          ...          ...         ...
# 14995    -0.649302    -0.999172    -0.857959    -0.140535   -0.077507
# 14996    -0.530164    -0.181764     0.506849     0.686812    0.600328
# 14997    -0.317786     0.068097    -0.034439     0.000896   -0.398650
# 14998    -0.355555    -0.661805    -0.082538     0.196148    0.832049
# 14999     0.924946     0.913918     0.233714     0.842296   -0.468100
#
#        onboard_ay  onboard_az  onboard_gx  onboard_gy  onboard_gz
# 0       -0.253852    0.922974    0.252406   -0.954925    0.239031
# 1       -0.067383   -0.387316    0.516054   -0.819110    0.050148
# 2       -0.325989   -0.811631    0.595114   -0.883234    0.242658
# 3        0.512283   -0.311292    0.949121   -0.867171   -0.419372
# 4        0.439695    0.424414   -0.143569    0.094118    0.629934
# ...           ...         ...         ...         ...         ...
# 14995   -0.675474    0.885395   -0.691436    0.998024   -0.623142
# 14996   -0.020635   -0.612954    0.968114   -0.329008    0.473525
# 14997   -0.966463   -0.102859   -0.289553   -0.077635   -0.845528
# 14998   -0.537941   -0.489915   -0.454375   -0.279517    0.360186
# 14999   -0.202552    0.706391   -0.324280   -0.563530    0.069974
#
# [15000 rows x 20 columns]

# %%
dummy_dict = {'gesture_0':0,'gesture_1':1,'gesture_2':2,'gesture_3':3,'gesture_4':4}
# Write the dictionary to the JSON file
with open('dummy_gesture_dict.json', 'w') as json_file:
    json.dump(dummy_dict, json_file)
